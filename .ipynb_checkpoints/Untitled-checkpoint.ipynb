# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
car_data_df=pd.read_csv('carData.csv')
car_data_df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
car_data_df.keys()
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
print(car_data_df.dtypes)
# Out:
# Car_Name          object
# Year               int64
# Selling_Price    float64
# Present_Price    float64
# Kms_Driven         int64
# Fuel_Type         object
# Seller_Type       object
# Transmission      object
# Owner              int64
# dtype: object

# %%
# car_data_df['PRIX'] = car_data_df.target
car_data_df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
car_data_df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
car_data_df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
liste=list(car_data_df.columns)
for i in range(4):
    name=liste[i+1]
    mean = car_data_df[f'{name}'].mean()
    print(f'{liste[i+1]} Mean')
    print(f'{mean}\n------------')
# Out:
# Year Mean
# 2013.6279069767443
# ------------
# Selling_Price Mean
# 4.661295681063127
# ------------
# Present_Price Mean
# 7.628471760797344
# ------------
# Kms_Driven Mean
# 36947.20598006644
# ------------

# %%
for i in range(4):
    name=liste[i+1]
    median = car_data_df[f'{name}'].median()
    print(f'{liste[i+1]} Median')
    print(f'{median}\n------------')
# Out:
# Year Median
# 2014.0
# ------------
# Selling_Price Median
# 3.6
# ------------
# Present_Price Median
# 6.4
# ------------
# Kms_Driven Median
# 32000.0
# ------------

# %%
car_data_df.hist(column=["Year"],figsize=(14,8))
# Out:
# array([[<AxesSubplot:title={'center':'Year'}>]], dtype=object)

# %%
car_data_df.boxplot(column=["Year"],figsize=(18,9))
# Out:
# <AxesSubplot:>

# %%
car_data_df.hist(column=["Selling_Price","Present_Price"],figsize=(18,9))
# Out:
# array([[<AxesSubplot:title={'center':'Present_Price'}>,
#         <AxesSubplot:title={'center':'Selling_Price'}>]], dtype=object)

# %%
car_data_df.boxplot(column=["Selling_Price","Present_Price"],figsize=(18,9))
# Out:
# <AxesSubplot:>

# %%
car_data_df.hist(column=["Kms_Driven"],figsize=(18,9))
# Out:
# array([[<AxesSubplot:title={'center':'Kms_Driven'}>]], dtype=object)

# %%
car_data_df.boxplot(column=["Kms_Driven"],figsize=(18,9))
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns
sns.set_theme(style="ticks")
g = sns.catplot(x="Year", y="Selling_Price", hue="Transmission", data=car_data_df,height=8.27, aspect=11.7/8.27)
g.set_xticklabels(rotation=30)

# %%
sns.set_theme(style="ticks")
g = sns.catplot(x="Year", y="Present_Price", hue="Transmission", data=car_data_df,height=8.27, aspect=11.7/8.27)
g.set_xticklabels(rotation=30)

# %%
g = sns.catplot(x="Year", y="Selling_Price", hue="Transmission", data=car_data_df, kind="violin",height=8.27, aspect=11.7/8.27)
g.set_xticklabels(rotation=30)

# %%
g = sns.catplot(x="Year", y="Present_Price", data=car_data_df,hue="Transmission", kind="violin",height=8.27, aspect=11.7/8.27)
g.set_xticklabels(rotation=30)
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
ax = sns.boxplot(x="Year", y="Selling_Price", data=car_data_df)
ax = sns.stripplot(x="Year", y="Selling_Price", data=car_data_df, color=".3")

# %%
g = sns.scatterplot(x="Present_Price", y="Kms_Driven", hue="Transmission", data=car_data_df)
plt.xlabel("Present_Price", size=16)
plt.ylabel("Kms_Driven", size=16)
plt.title("Present_Price vs Kms_Driven", size=24)
# Out:
# Text(0.5, 1.0, 'Present_Price vs Kms_Driven')

# %%
g = sns.scatterplot(x="Selling_Price", y="Present_Price", hue="Transmission", data=car_data_df)
plt.xlabel("Selling_Price", size=16)
plt.ylabel("Present_Price", size=16)
plt.title("Selling_Price vs Present_Price", size=24)
# Out:
# Text(0.5, 1.0, 'Selling_Price vs Present_Price')

# %%
sns.set_theme(style="whitegrid")
ax = sns.boxenplot(x=car_data_df["Year"])

# %%
sns.set_theme(style="whitegrid")
ax = sns.boxenplot(x=car_data_df["Selling_Price"])

# %%
ax = sns.boxenplot(x=car_data_df["Kms_Driven"])

# %%
ax = sns.boxenplot(x=car_data_df["Present_Price"])

# %%
g = sns.scatterplot(x="Selling_Price", y="Kms_Driven", hue="Transmission", data=car_data_df)
plt.xlabel("Selling_Price", size=16)
plt.ylabel("Kms_Driven", size=16)
plt.title("Selling_Price vs Kms_Driven", size=24)
# Out:
# Text(0.5, 1.0, 'Selling_Price vs Kms_Driven')

# %%
import seaborn as sns 
matrice_corr = car_data_df.corr()
f, ax = plt.subplots(figsize =(9, 8)) 
sns.heatmap(matrice_corr, ax = ax, cmap ="YlGnBu", linewidths = 0.1,annot=True)
# Out:
# <AxesSubplot:>

# %%
from matplotlib import pyplot
pyplot.scatter(car_data_df['Year'], car_data_df['Selling_Price'])
pyplot.show()

# %%
from scipy.stats import spearmanr
corr, _ = spearmanr(car_data_df['Selling_Price'], car_data_df['Year'])
print('Spearmans correlation: %.3f' % corr)
# Out:
# Spearmans correlation: 0.283

# %%
from scipy.stats import pearsonr
corr, _ = pearsonr(car_data_df['Selling_Price'], car_data_df['Year'])
print('Pearsons correlation: %.3f' % corr)
# Out:
# Pearsons correlation: 0.236

# %%
from numpy import cov
# calculate covariance matrix
covariance = cov(car_data_df['Selling_Price'], car_data_df['Year'])
print(covariance)
# Out:
# [[25.83497332  3.47061705]
#  [ 3.47061705  8.36108527]]

# %% [markdown]
# # Linear Regression With One Variable using Scikitlearn

# %%
X = pd.DataFrame(np.c_[car_data_df['Year']], columns = ['Year'])
Y = car_data_df['Selling_Price']
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=5)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (240, 1)
# (61, 1)
# (240,)
# (61,)

# %%
#entrainement du modèle
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
 
lmodellineaire = LinearRegression()
lmodellineaire.fit(X_train, Y_train)
Y_pred = lmodellineaire.predict(X_test)
plt.scatter(Y_test, Y_pred)
plt.xlabel("Prices: $Y_i$")
plt.ylabel("Predicted prices: $\hat{Y}_i$")
plt.title("Prices vs Predicted prices: $Y_i$ vs $\hat{Y}_i$")
# Out:
# Text(0.5, 1.0, 'Prices vs Predicted prices: $Y_i$ vs $\\hat{Y}_i$')

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(Y_test, Y_pred)
print(mse,lmodellineaire.intercept_,lmodellineaire.coef_)
# Out:
# 25.713611967567978 -844.9349089573319 [0.42187272]

# %%
x = car_data_df['Year']
y = car_data_df['Selling_Price']

# %%
plt.plot(x, y, 'o', label='original data')
plt.plot(x, lmodellineaire.intercept_ + lmodellineaire.coef_*x, 'r', label='fitted line')
plt.legend()
plt.show()

# %%
# Evaluation du training set
from sklearn.metrics import r2_score
y_train_predict = lmodellineaire.predict(X_train)
rmse = (np.sqrt(mean_squared_error(Y_train, y_train_predict)))
r2 = r2_score(Y_train, y_train_predict)
 
print('La performance du modèle sur la base dapprentissage')
print('--------------------------------------')
print('Lerreur quadratique moyenne est {}'.format(rmse))
print('le score R2 est {}'.format(r2))
print('\n')
 
# model evaluation for testing set
y_test_predict = lmodellineaire.predict(X_test)
rmse = (np.sqrt(mean_squared_error(Y_test, y_test_predict)))
r2 = r2_score(Y_test, y_test_predict)
 
print('La performance du modèle sur la base de test')
print('--------------------------------------')
print('Lerreur quadratique moyenne est {}'.format(rmse))
print('le score R2 est {}'.format(r2))
# Out:
# La performance du modèle sur la base dapprentissage
# --------------------------------------
# Lerreur quadratique moyenne est 4.895998184924539
# le score R2 est 0.05754438487743574
#
#
# La performance du modèle sur la base de test
# --------------------------------------
# Lerreur quadratique moyenne est 5.070859095613679
# le score R2 est 0.04199446998817913

# %% [markdown]
# # Linear Regression With One Variable Using Numpy

# %%
model = np.polyfit(x, y, 1)
model
# Out:
# array([ 4.15091695e-01, -8.31178925e+02])

# %% [markdown]
# # Prediction Selling_Price

# %%
predict = np.poly1d(model)
# years = range(2012,2020)
# for year in years:
#     print(year,predict(year))

# %%
from sklearn.metrics import r2_score
r2_score(y, predict(x))
# Out:
# 0.055762562511127545

# %%
x_lin_reg = range(2003, 2020)
y_lin_reg = predict(x_lin_reg)
plt.scatter(x, y)
plt.plot(x_lin_reg, y_lin_reg, c = 'r')

# %% [markdown]
# # Linear Regression With One Variable Using Seaborn

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
g = sns.jointplot(x="Year", y="Selling_Price", data=car_data_df,
                  kind="reg", truncate=False,
                  xlim=(2003, 2018), ylim=(0, 12),
                  color="m", height=15)

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
g = sns.jointplot(x="Present_Price", y="Selling_Price", data=car_data_df,
                  kind="reg", truncate=False,
                  xlim=(0, 12), ylim=(0, 12),
                  color="m", height=15)

# %%
sns.lmplot(x="Year", y="Selling_Price", hue="Seller_Type",
           col="Fuel_Type", row="Transmission", data=car_data_df);

# %% [markdown]
# # Linear Regression With One Variable Using statsmodels

# %%
# For statistics. Requires statsmodels 5.0 or more
from statsmodels.formula.api import ols
# Analysis of Variance (ANOVA) on linear models
from statsmodels.stats.anova import anova_lm
data = pd.DataFrame({'Year': car_data_df['Year'], 'Selling_Price': car_data_df['Selling_Price']})
# Fit the model
model = ols("y ~ x", data).fit()
model

# %%
# Print the summary
print(model.summary())
# Peform analysis of variance on fitted linear model
anova_results = anova_lm(model)
print('\nANOVA results')
print(anova_results)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.056
# Model:                            OLS   Adj. R-squared:                  0.053
# Method:                 Least Squares   F-statistic:                     17.66
# Date:                Fri, 18 Dec 2020   Prob (F-statistic):           3.50e-05
# Time:                        14:27:38   Log-Likelihood:                -907.35
# No. Observations:                 301   AIC:                             1819.
# Df Residuals:                     299   BIC:                             1826.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -831.1789    198.910     -4.179      0.000   -1222.620    -439.737
# ...

# %%
# Retrieve the parameter estimates
offset, coef = model._results.params
plt.plot(x, x*coef + offset, c = 'r')
plt.xlabel('x')
plt.ylabel('y')
plt.scatter(x,y)
plt.show()

# %% [markdown]
# # Linear Regression With One Variable Using Scipy

# %%
from scipy import stats
slope, intercept, r_value, p_value, std_err = stats.linregress(car_data_df['Year'], car_data_df['Selling_Price'])
print("slope: %f    intercept: %f" % (slope, intercept))
# Out:
# slope: 0.415092    intercept: -831.178925

# %%
print("R-squared: %f" % r_value**2)
# Out:
# R-squared: 0.055763

# %%
plt.plot(x, y, 'o', label='original data')
plt.plot(x, intercept + slope*x, 'r', label='fitted line')
plt.legend()
plt.show()

# %% [markdown]
# # MultiVariable Linear regression With Using SkLearn

# %%
from sklearn.preprocessing import LabelEncoder
car_data_df1=car_data_df.apply(LabelEncoder().fit_transform)
matrice_corr1=car_data_df1.corr()
f, ax = plt.subplots(figsize =(9, 8)) 
sns.heatmap(matrice_corr1, ax = ax, cmap ="YlGnBu", linewidths = 0.1,annot=True)
# Out:
# <AxesSubplot:>

# %%
car_data_df1.head()
# Out:
#    Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0        90    11             59             57          86          2
# 1        93    10             78            104         135          1
# 2        68    14            112            106          26          2
# 3        96     8             52             49          18          2
# 4        92    11             76             73         134          1
#
#    Seller_Type  Transmission  Owner
# 0            0             1      0
# 1            0             1      0
# 2            0             1      0
# 3            0             1      0
# 4            0             1      0

# %%
car_data_df1.keys()
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
#on utilise seulement 4 variables explicatives
X=pd.DataFrame(np.c_[car_data_df1['Car_Name'],car_data_df['Year'],car_data_df['Present_Price'],car_data_df['Kms_Driven'],
                     car_data_df1['Fuel_Type'],car_data_df1['Seller_Type'],car_data_df1['Transmission'],car_data_df['Owner']], columns = ['Car_Name','Year','Present_Price','Kms_Driven','Fuel_Type','Seller_Type','Transmission','Owner'])
Y = car_data_df['Selling_Price']
 
#base d'apprentissage et base de test
from sklearn.model_selection import train_test_split
 
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=5)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (240, 8)
# (61, 8)
# (240,)
# (61,)

# %%
#entrainement du modèle
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
 
lmodellineaire = LinearRegression()
lmodellineaire.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
# Evaluation du training set
from sklearn.metrics import r2_score
y_train_predict = lmodellineaire.predict(X_train)
rmse = (np.sqrt(mean_squared_error(Y_train, y_train_predict)))
r2 = r2_score(Y_train, y_train_predict)
 
print('La performance du modèle sur la base dapprentissage')
print('--------------------------------------')
print('Lerreur quadratique moyenne est {}'.format(rmse))
print('le score R2 est {}'.format(r2))
print('\n')
 
# model evaluation for testing set
y_test_predict = lmodellineaire.predict(X_test)
rmse = (np.sqrt(mean_squared_error(Y_test, y_test_predict)))
r2 = r2_score(Y_test, y_test_predict)
 
print('La performance du modèle sur la base de test')
print('--------------------------------------')
print('Lerreur quadratique moyenne est {}'.format(rmse))
print('le score R2 est {}'.format(r2))
# Out:
# La performance du modèle sur la base dapprentissage
# --------------------------------------
# Lerreur quadratique moyenne est 1.7886596147534
# le score R2 est 0.8742135638021382
#
#
# La performance du modèle sur la base de test
# --------------------------------------
# Lerreur quadratique moyenne est 1.8989463272500802
# le score R2 est 0.8656522771331384

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(Y_test, Y_pred)
print(mse,lmodellineaire.intercept_,lmodellineaire.coef_)
# Out:
# 25.713611967567978 -678.3316040443527 [-2.26144479e-03  3.39877283e-01  4.54755494e-01 -1.70614089e-05
#  -1.55256061e+00 -1.29766351e+00 -9.96362688e-01 -8.10838785e-01]

# %% [markdown]
# # MultiVariable Linear regression With Using SkLearn without presentprice

# %%
#on utilise seulement 4 variables explicatives
X=pd.DataFrame(np.c_[car_data_df1['Car_Name'],car_data_df['Year'],car_data_df['Kms_Driven'],
                     car_data_df1['Fuel_Type'],car_data_df1['Seller_Type'],car_data_df1['Transmission'],car_data_df['Owner']], columns = ['Car_Name','Year','Kms_Driven','Fuel_Type','Seller_Type','Transmission','Owner'])
Y = car_data_df1['Selling_Price']
 
#base d'apprentissage et base de test
from sklearn.model_selection import train_test_split
 
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=5)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (240, 7)
# (61, 7)
# (240,)
# (61,)

# %%
#entrainement du modèle
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
 
lmodellineaire = LinearRegression()
lmodellineaire.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
# Evaluation du training set
from sklearn.metrics import r2_score
y_train_predict = lmodellineaire.predict(X_train)
rmse = (np.sqrt(mean_squared_error(Y_train, y_train_predict)))
r2 = r2_score(Y_train, y_train_predict)
 
print('La performance du modèle sur la base dapprentissage')
print('--------------------------------------')
print('Lerreur quadratique moyenne est {}'.format(rmse))
print('le score R2 est {}'.format(r2))
print('\n')
 
# model evaluation for testing set
y_test_predict = lmodellineaire.predict(X_test)
rmse = (np.sqrt(mean_squared_error(Y_test, y_test_predict)))
r2 = r2_score(Y_test, y_test_predict)
 
print('La performance du modèle sur la base de test')
print('--------------------------------------')
print('Lerreur quadratique moyenne est {}'.format(rmse))
print('le score R2 est {}'.format(r2))
# Out:
# La performance du modèle sur la base dapprentissage
# --------------------------------------
# Lerreur quadratique moyenne est 21.92713157754957
# le score R2 est 0.7339103748039277
#
#
# La performance du modèle sur la base de test
# --------------------------------------
# Lerreur quadratique moyenne est 22.45479593020761
# le score R2 est 0.748815477512414

# %%
mse = mean_squared_error(Y_test, y_test_predict)
print(mse,lmodellineaire.intercept_,lmodellineaire.coef_)
# Out:
# 504.21786026726824 -10578.728281745862 [ 1.72479511e-01  5.31067254e+00  1.66528963e-04 -1.72963812e+01
#  -5.06916165e+01 -1.95476124e+01  4.89099513e+00]

# %% [markdown]
# # MultiVariable Linear regression With Data Cleaning and Using SkLearn

# %%
car_data_df.keys()
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
car_data_df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %% [markdown]
# ### Data Cleaning (for given conditions)

# %%
car_data_df2=car_data_df[car_data_df.Year > 2012]
car_data_df2=car_data_df2[car_data_df2.Kms_Driven < 100000]
car_data_df2=car_data_df2[car_data_df2.Transmission == "Manual"]
car_data_df2.drop("Transmission", axis=1)
car_data_df2
# Out:
#           Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0             ritz  2014           3.35           5.59       27000    Petrol
# 1              sx4  2013           4.75           9.54       43000    Diesel
# 2             ciaz  2017           7.25           9.85        6900    Petrol
# 4            swift  2014           4.60           6.87       42450    Diesel
# 5    vitara brezza  2018           9.25           9.83        2071    Diesel
# ..             ...   ...            ...            ...         ...       ...
# 295           city  2015           8.55          13.09       60076    Diesel
# 296           city  2016           9.50          11.60       33988    Diesel
# 297           brio  2015           4.00           5.90       60000    Petrol
# 299           city  2017          11.50          12.50        9000    Diesel
# 300           brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# ...

# %% [markdown]
# ### One Variable(Year) Linear regression With Using SkLearn After Data Cleaning

# %%
g = sns.jointplot(x="Year", y="Selling_Price", data=car_data_df2,
                  kind="reg", truncate=False,
                  xlim=(2012, 2019), ylim=(0, 12),
                  color="m", height=15)

# %% [markdown]
# ### Correaltion matrix of data after Data Cleaning

# %%
car_data_df3=car_data_df2.apply(LabelEncoder().fit_transform)
matrice_corr1=car_data_df3.corr()
f, ax = plt.subplots(figsize =(9, 8)) 
sns.heatmap(matrice_corr1, ax = ax, cmap ="YlGnBu", linewidths = 0.1,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Dsiplaying premier 5 datas

# %%
car_data_df3.head()
# Out:
#    Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0        66     1             42             48          73          2
# 1        69     0             56             83         112          1
# 2        48     4             84             85          22          2
# 4        68     1             54             61         111          1
# 5        71     5             99             84           5          1
#
#    Seller_Type  Transmission  Owner
# 0            0             0      0
# 1            0             0      0
# 2            0             0      0
# 4            0             0      0
# 5            0             0      0

# %% [markdown]
# ### Data preparation

# %%
X=pd.DataFrame(np.c_[car_data_df3['Car_Name'],car_data_df2['Year'],car_data_df2['Kms_Driven'],car_data_df2['Present_Price'],
                     car_data_df3['Fuel_Type'],car_data_df3['Seller_Type'],car_data_df2['Owner'],], columns = ['Car_Name','Year','Kms_Driven','Present_Price','Fuel_Type','Seller_Type','Owner'])
Y = car_data_df3['Selling_Price']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=5)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (151, 7)
# (38, 7)
# (151,)
# (38,)

# %% [markdown]
# ### Training model

# %%
#entrainement du modèle
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
lmodellineaire = LinearRegression()
lmodellineaire.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Evaluation training set

# %%
# Evaluation du training set
from sklearn.metrics import r2_score
y_train_predict = lmodellineaire.predict(X_train)
rmse = (np.sqrt(mean_squared_error(Y_train, y_train_predict)))
r2 = r2_score(Y_train, y_train_predict)
 
print('La performance du modèle sur la base dapprentissage')
print('--------------------------------------')
print('Lerreur quadratique moyenne est {}'.format(rmse))
print('le score R2 est {}'.format(r2))
# Out:
# La performance du modèle sur la base dapprentissage
# --------------------------------------
# Lerreur quadratique moyenne est 7.553431963925913
# le score R2 est 0.9451197569491572

# %% [markdown]
# ### Testing set

# %%
# model evaluation for testing set
y_test_predict = lmodellineaire.predict(X_test)
rmse = (np.sqrt(mean_squared_error(Y_test, y_test_predict)))
r2 = r2_score(Y_test, y_test_predict)
 
print('La performance du modèle sur la base de test')
print('--------------------------------------')
print('Lerreur quadratique moyenne est {}'.format(rmse))
print('le score R2 est {}'.format(r2))
# Out:
# La performance du modèle sur la base de test
# --------------------------------------
# Lerreur quadratique moyenne est 9.555562983103822
# le score R2 est 0.8841911475878199

# %% [markdown]
# # 2 Variables(Year and Present Price) Linear regression With Using SkLearn

# %%
######################################## Data preparation #########################################
from sklearn import linear_model
X = car_data_df2[['Year', 'Present_Price']].values
Y = car_data_df2['Selling_Price']

######################## Prepare model data point for visualization ###############################
x = X[:, 0]
y = X[:, 1]
z = Y
x_pred = np.linspace(2012, 2019, 15)   # range of porosity values
y_pred = np.linspace(0, 20, 15)  # range of brittleness values
xx_pred, yy_pred = np.meshgrid(x_pred, y_pred)
model_viz = np.array([xx_pred.flatten(), yy_pred.flatten()]).T

################################################ Train #############################################

ols = linear_model.LinearRegression()
model = ols.fit(X, Y)
predicted = model.predict(model_viz)

############################################## Evaluate ############################################

r2 = model.score(X, Y)

############################################## Plot ################################################

plt.style.use('default')

fig = plt.figure(figsize=(12, 4))

ax1 = fig.add_subplot(131, projection='3d')
ax2 = fig.add_subplot(132, projection='3d')
ax3 = fig.add_subplot(133, projection='3d')

axes = [ax1, ax2, ax3]

for ax in axes:
    ax.plot(x, y, z, color='k', zorder=15, linestyle='none', marker='o', alpha=0.5)
    ax.scatter(xx_pred.flatten(), yy_pred.flatten(), predicted, facecolor=(0,0,0,0), s=20, edgecolor='#70b3f0')
    ax.set_xlabel('Year', fontsize=12)
    ax.set_ylabel('Present_Price', fontsize=12)
    ax.set_zlabel('Selling_Price', fontsize=12)
    ax.locator_params(nbins=4, axis='x')
    ax.locator_params(nbins=5, axis='x')
    
    
ax1.view_init(elev=8, azim=160)
ax2.view_init(elev=45, azim=-30)
ax3.view_init(elev=17, azim=25)

fig.suptitle('$R^2 = %.2f$' % r2, fontsize=20)

fig.tight_layout()

# %% [markdown]
# # Prediction of Selling Price

# %%
# function for prediction
def prediction(year, presentprice):
    predictedPrice = ols.predict([[year, presentprice]])
    return predictedPrice[0].round(2)


# taking parameters from user
year=int(input('Quel modèle devrait être votre voiture?(Year, ex: 2014) : '))
presentprice=float(input('Que devrait valoir votre voiture maintenant?(Present_Price, ex: 14.5) : '))
prediction(year, presentprice)
# Out:
# Quel modèle devrait être votre voiture?(Year, ex: 2014) : 2018
# Que devrait valoir votre voiture maintenant?(Present_Price, ex: 14.5) : 8
# 7.12
